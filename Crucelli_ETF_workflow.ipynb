# %% [markdown]
# # Workflow Crucelli ETF
# Questo notebook esegue in sequenza:
# - update_data.py
# - update_upcoming_champions.py
# - update_upcoming.py
# - filter_teams_1_2026.py
# - filter_teams_2_2026.py
# - filter_teams_3_2026.py
# - filter_teams_4_2026.py
# - filter_teams_5_2026.py
# - betting.py
#
# Ogni cella esegue uno script e mostra l'output.

# %%
# Importazione delle librerie necessarie
import pandas as pd
import os
import sys
import json
from datetime import datetime

# %%
# Esecuzione di update_data.py
# !python src/data_update/update_data.py
# Out:
# 🔄 Aggiornamento partite in corso...
# Fetching matches for Saudi Professional League (307), season 2022...
# Fetching matches for Saudi Professional League (307), season 2023...
# Fetching matches for Saudi Professional League (307), season 2024...
# Fetching matches for Saudi Professional League (307), season 2025...
# Fetching matches for HNL (210), season 2022...
# Fetching matches for HNL (210), season 2023...
# Fetching matches for HNL (210), season 2024...
# Fetching matches for HNL (210), season 2025...
# Fetching matches for Ligue 1 (61), season 2022...
# Fetching matches for Ligue 1 (61), season 2023...
# Fetching matches for Ligue 1 (61), season 2024...
# Fetching matches for Ligue 1 (61), season 2025...
# Fetching matches for Bundesliga (78), season 2022...
# Fetching matches for Bundesliga (78), season 2023...
# Fetching matches for Bundesliga (78), season 2024...
# Fetching matches for Bundesliga (78), season 2025...
# ...

# %%
# Esecuzione di update_upcoming_champions.py
# !python src/data_update/update_upcoming_champions.py
# Out:
# ✅ Partite trovate: 8
# ✅ Salvate 8 partite normalizzate in data/raw/upcoming_champions.csv

# %%
# Esecuzione di update_upcoming.py
# !python src/data_update/update_upcoming.py
# Out:
# Fetching upcoming matches for Saudi Professional League (307)...
# Fetching upcoming matches for HNL (210)...
# Fetching upcoming matches for Ligue 1 (61)...
# Fetching upcoming matches for Bundesliga (78)...
# Fetching upcoming matches for Premier League (39)...
# Fetching upcoming matches for Serie A (135)...
# Fetching upcoming matches for Eredivisie (88)...
# Fetching upcoming matches for Liga Portugal (94)...
# Fetching upcoming matches for Premiership (179)...
# Fetching upcoming matches for LaLiga (140)...
# Fetching upcoming matches for Super Lig (203)...
# ✅ upcoming_matches.csv aggiornato e normalizzato!

# %%
# Applicazione del filtro 1
# !python src/queries/filter_teams_1_2026.py
# Out:
# ✅ Filtro 1 completato. File salvato in /Users/andrea/Desktop/crucelli/data/processed/selected_teams_filter1.csv
#      team_id            team_name  ...  goal_diff current_matchday
# 52      2932    al-hilal saudi fc  ...         37               21
# 54      2939             al-nassr  ...         35               21
# 100      620        dinamo zagreb  ...         31               22
# 167       85  paris saint germain  ...         30               22
# 169       81            marseille  ...         19               22
# 238      157        bayern munich  ...         63               22
# 239      165    borussia dortmund  ...         27               22
# 316       42              arsenal  ...         32               27
# 317       50      manchester city  ...         30               27
# 396      505                inter  ...         39               25
# 398      492               napoli  ...         13               25
# ...

# %%
# Applicazione del filtro 2
# !python src/queries/filter_teams_2_2026.py
# Out:
# ✅ Filtro 2 completato. File salvato in data/processed/selected_teams_filter2.csv
#            team_name                league_name  ...  champions_threshold_prev  diff
# 0            as roma                    serie a  ...                        70    -1
# 1        aston villa             premier league  ...                        69    -3
# 2  borussia dortmund                 bundesliga  ...                        57     0
# 3               lyon                    ligue 1  ...                        60    -3
# 4         fenerbahce                  super lig  ...                        84     0
# 5     al-ahli jeddah  saudi professional league  ...                        68    -1
#
# [6 rows x 5 columns]

# %%
# Applicazione del filtro 3
# !python src/queries/filter_teams_3_2026.py
# Out:
# ✅ Filtro 3 completato. File salvato in data/processed/selected_teams_filter3.csv
#   team_name     league_name  points  ...  matches  matches_champ diff_partite
# 0  juventus         serie a      46  ...     None           None         None
# 1   chelsea  premier league      44  ...     None           None         None
#
# [2 rows x 8 columns]

# %%
# Applicazione del filtro 4
# !python src/queries/filter_teams_4_2026.py
# Out:
# ✅ Filtro 4 completato. File salvato in data/processed/selected_teams_filter4.csv
#               team_name           league_name  ...  matches_prima  diff_partite
# 0               arsenal        premier league  ...           None          None
# 1       manchester city        premier league  ...           None          None
# 2         bayern munich            bundesliga  ...           None          None
# 3     borussia dortmund            bundesliga  ...           None          None
# 4                 inter               serie a  ...           None          None
# 5              ac milan               serie a  ...           None          None
# 6                  lens               ligue 1  ...           None          None
# 7   paris saint germain               ligue 1  ...           None          None
# 8         psv eindhoven            eredivisie  ...           None          None
# 9             feyenoord            eredivisie  ...           None          None
# ...

# %%
# Applicazione del filtro 5
# !python src/queries/filter_teams_5_2026.py
# Out:
# ✅ Filtro 5 completato. File salvato in data/processed/selected_teams_filter5.csv
#               team_name           league_name  ...  matches_seconda  diff_partite
# 0               arsenal        premier league  ...             None          None
# 1       manchester city        premier league  ...             None          None
# 2         bayern munich            bundesliga  ...             None          None
# 3     borussia dortmund            bundesliga  ...             None          None
# 4                 inter               serie a  ...             None          None
# 5   paris saint germain               ligue 1  ...             None          None
# 6         psv eindhoven            eredivisie  ...             None          None
# 7             feyenoord            eredivisie  ...             None          None
# 8               rangers  scottish premiership  ...             None          None
# ...

# %%
# Esecuzione di betting.py
# !python src/queries/betting.py
# Out:
# ✅ Merge completato. File salvato in data/processed/bet.csv
#
#     squadra selezionata            campionato      squadra in casa  ... F4 F5  oggi
# 3             marseille               ligue 1    stade brestois 29  ...        OGGI
# 14             juventus               serie a             juventus  ...
# 10        bayern munich            bundesliga        bayern munich  ...  x  x
# 0               chelsea        premier league              chelsea  ...
# 11          aston villa        premier league          aston villa  ...
# 9                  lens               ligue 1                 lens  ...  x
# 2                 inter               serie a                lecce  ...  x  x
# 22          galatasaray             super lig            konyaspor  ...  x  x
# 19    borussia dortmund            bundesliga           rb leipzig  ...  x  x
# 4         psv eindhoven            eredivisie        psv eindhoven  ...  x  x
# ...
